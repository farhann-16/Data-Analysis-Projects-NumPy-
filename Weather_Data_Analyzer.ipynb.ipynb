# %% [markdown]
# # 🌡️ Weather Data Analyzer (NumPy Project)
# Analyze 7-day temperature data for multiple cities using NumPy features:
# - 2D Arrays
# - Axis-based operations
# - Broadcasting (Heatwave simulation)
# - Average, Min, Max, Standard Deviation

# %%
import numpy as np

# %%
# 2D array of temperatures for 4 cities over 7 days
temperatures = np.array([
    [32, 34, 35, 33, 31, 30, 29],   # City A
    [28, 30, 29, 27, 26, 25, 24],   # City B
    [35, 36, 37, 35, 34, 33, 32],   # City C
    [22, 23, 21, 20, 19, 18, 17]    # City D
])

# %%
city_avg = np.mean(temperatures, axis=1)
day_avg = np.mean(temperatures, axis=0)

print("📊 Average Temperature Per City:", city_avg)
print("📆 Average Temperature Per Day:", day_avg)
# Out:
# 📊 Average Temperature Per City: [32.         27.         34.57142857 20.        ]
# 📆 Average Temperature Per Day: [29.25 30.75 30.5  28.75 27.5  26.5  25.5 ]

# %%
city_min = np.min(temperatures, axis=1)
city_max = np.max(temperatures, axis=1)
city_std = np.std(temperatures, axis=1)

for i in range(len(temperatures)):
    print(f"City {i}: Avg={city_avg[i]:.1f}°C | Min={city_min[i]}°C | Max={city_max[i]}°C | Std Dev={city_std[i]:.2f}")
# Out:
# City 0: Avg=32.0°C | Min=29°C | Max=35°C | Std Dev=2.00
# City 1: Avg=27.0°C | Min=24°C | Max=30°C | Std Dev=2.00
# City 2: Avg=34.6°C | Min=32°C | Max=37°C | Std Dev=1.59
# City 3: Avg=20.0°C | Min=17°C | Max=23°C | Std Dev=2.00

# %%
# Add 2°C to simulate a heatwave
heatwave = temperatures + 2
print("🌞 Temperatures after Heatwave:\n", heatwave)
# Out:
# 🌞 Temperatures after Heatwave:
#  [[34 36 37 35 33 32 31]
#  [30 32 31 29 28 27 26]
#  [37 38 39 37 36 35 34]
#  [24 25 23 22 21 20 19]]

# %%
hottest_city = np.argmax(city_avg)
print(f"🔥 City {hottest_city} has the highest average temperature: {city_avg[hottest_city]:.1f}°C")
# Out:
# 🔥 City 2 has the highest average temperature: 34.6°C

# %%
import matplotlib.pyplot as plt

days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
cities = ['City A', 'City B', 'City C', 'City D']

plt.figure(figsize=(10, 6))
for i in range(len(temperatures)):
    plt.plot(days, temperatures[i], label=cities[i], marker='o')

plt.title("📈 Temperature Trends for 4 Cities (7 Days)")
plt.xlabel("Days")
plt.ylabel("Temperature (°C)")
plt.legend()
plt.grid(True)
plt.tight_layout()
# plt.savefig("temperature_trends.png")
plt.show()
# Out:
# C:\Users\Farhan Diwan\AppData\Local\Temp\ipykernel_19012\2039417424.py:15: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()

# %%
plt.figure(figsize=(8, 5))
plt.bar(cities, city_avg, color=['orange', 'blue', 'red', 'green'])

plt.title("📊 Average Temperature per City")
plt.ylabel("Temperature (°C)")
plt.tight_layout()
plt.savefig("average_temperature_per_city.png")
plt.show()
# Out:
# C:\Users\Farhan Diwan\AppData\Local\Temp\ipykernel_19012\1980228955.py:6: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Farhan Diwan\AppData\Local\Temp\ipykernel_19012\1980228955.py:7: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.savefig("average_temperature_per_city.png")
# C:\Users\Farhan Diwan\anaconda3\envs\Farhanenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### ✅ Summary of What You Learned
#
# - How to create and work with **2D arrays** in NumPy
# - Use of **axis-based operations** for row/column-level analysis
# - **Broadcasting** concept in NumPy for efficient calculations
# - Basic statistical functions: `mean`, `min`, `max`, `std`
